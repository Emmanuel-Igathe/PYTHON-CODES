# %%
#STRING DATATYPE

# %% [markdown]
# #### SLICING

# %%
#SLICING IS GRABBING A CHUNCK OR SUBSTRING OF A STRING

# %%
text = "NAIROBI"

# %%
print(text[0:3])
# Out:
# NAI

# %%
print(text[3:])
# Out:
# ROBI

# %%
print(text[2:])
# Out:
# IROBI

# %%
name = "Emmanuel"

# %%
print(name[0:5])
# Out:
# Emman

# %%
print(name[3:7])
# Out:
# anue
