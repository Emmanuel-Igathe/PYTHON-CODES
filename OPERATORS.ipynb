# %% [markdown]
# # OPERATORS

# %% [markdown]
# ## ARITHMETPIC OPERATORS

# %%
#ADDITION OPERATOR

# %%
#Unary plus

# %%
10 + 23
# Out:
# 33

# %%
+ 45  #tHE OPERATOR MAKES THE NUMBER A POSITIVE HENCE ITS A UNARY PLUS
# Out:
# 45

# %%
#SUBTRACTION OPERATOR

# %%
23 - 10
# Out:
# 13

# %%
- 13 #UNARY MINUS.iT MAKES THE NUMBER A NEGATIVE
# Out:
# -13

# %%
#MULTIPLICATION OPERATOR   * (ASTERIX)

# %%
2 * 5
# Out:
# 10

# %%
#DIVISION OPERATOR /  (GIVES FLOAT RESPONSE ALWAYS)

# %%
20 / 2
# Out:
# 10.0

# %%
#FLOOR DIVISION   (GIVES INTEGER RESPONSE)

# %%
20 // 2
# Out:
# 10

# %%
20 // 3
# Out:
# 6

# %%
5 // 2    #ANSWER IS SUPPOSED TO BE 2.5 BUT IS TRUNCATED TO 2
# Out:
# 2

# %%
#MODULUS  %     GIVES THE REMAINDER

# %%
20 % 3
# Out:
# 2

# %%
6 % 3
# Out:
# 0

# %%
10 % 4
# Out:
# 2

# %%
#EXPONENT OPERATOR ** IE ITS RAISING TO A POWER

# %%
2 ** 4
# Out:
# 16

# %%
5 ** 2
# Out:
# 25

# %%
# ASSOCITAVITY AND PRESENDENCE

# %%
10 + 5 * 2   #MULTIPLICATION BEATS ADDITION
#5 * 2
#10 + 10
#20
# Out:
# 20

# %%
(10 + 5) * 2   #PARENTHESES BEATS EVERYTHING IN PRESENDENCE
#10 + 5 = 15
#15 * 2 = 30
#30
# Out:
# 30

# %%
2 ** 3 ** 2        #EXPONENTIAL ASSOCIATIVITY IS FROM RIGHT TO LEFT
# 3 ** 2 = 9
# 2 ** 9 = 512
# 512
# Out:
# 512

# %%
#ASSIGNMENT OPERATOR =

# %%
#USED FOR ASSIGNING VALUES TO A VARIABLE

# %%
# IE X = 10

# %%
#EQUAL OPERATOR ==
2 == 2
# Out:
# True
