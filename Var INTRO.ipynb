# %% [markdown]
# #VARIABLES INTRODUCTION

# %%
#A NAME OR LABEL REFERRING TO A VALUE STORED IN A COMPUTER MEMORY
#Variable is data can change depending on the situation

# %%
#We use the assignment operator =

# %%
name = "Manu"
school = "TUK"
gender = "Manu"
disability = "Dwarfism"
city1 = "Nairobi"
city2 = "Syokimau"
age = 22

# %%
print(type(name))
# Out:
# <class 'str'>

# %%
print(type(age))
# Out:
# <class 'int'>

# %% [markdown]
# ### NAMING CONVENTIONS

# %% [markdown]
# #### SNAKE CASE

# %%
#use smallcase with underscores
total_monthly_revenues = "1000"

# %% [markdown]
# #### CAMEL CASE

# %%
#Mix small and uppercase letters
totalMonthlyRevenues = "1000"
