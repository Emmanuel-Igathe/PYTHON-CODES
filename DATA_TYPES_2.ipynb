# %% [markdown]
# <a href="https://colab.research.google.com/github/Emmanuel-Igathe/PYTHON-CODES/blob/main/DATA_TYPES_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #DATA TYPES
# ## DATA TYPES
# ### DATA TYPES
# #### DATA TYPES

# %% [markdown]
# ##NUMBERS

# %% [markdown]
# #INTEGERS
# ###### They are all numbers, positive,negative or zero

# %%
100
# Out:
# 100

# %% [markdown]
# #FLOATS
# ###### They are decimal point numbers

# %%
31.20
# Out:
# 31.2

# %% [markdown]
# #STRING
# ###### Are textual data or a series of characters

# %%
"Emmanuel"
# Out:
# 'Emmanuel'

# %% [markdown]
# #BOOLEAN
# ######They show if True or False

# %%
30 > 20
# Out:
# True

# %%
30 < 20
# Out:
# False

# %%
True + True
# Out:
# 2

# %%
True + False
# Out:
# 1

# %%
False + False
# Out:
# 0

# %%
True
# Out:
# True
