# %%
1 + 2
# Out:
# 3

# %%
import os
os.get.cwd
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 2
#       1 import os
# ----> 2 os.get.cwd
#
# AttributeError: module 'os' has no attribute 'get'
