# %% [markdown]
# # STRING DATATYPE

# %%
# Textual data or sequence of characters

# %%
# We write using "" or single quotation marks

# %%
print("Emmanuel")
# Out:
# Emmanuel

# %%
"Emmanuel"
# Out:
# 'Emmanuel'

# %%
a = "Manu"
b = "Igathe"

# %%
# concatination   ie to join two or more strings into one

# %%
a+" "+ b
# Out:
# 'Manu Igathe'

# %%
print(a+" "+b)
# Out:
# Manu Igathe

# %%
#Repetition

# %%
a * 6
# Out:
# 'ManuManuManuManuManuManu'

# %%
print(a * 6)
# Out:
# ManuManuManuManuManuManu

# %%
a = "BETA"

# %%
print(a)
# Out:
# BETA

# %%
a[0]
# Out:
# 'B'

# %%
a[1]
# Out:
# 'E'
