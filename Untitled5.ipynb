# %% [markdown]
# # STRING DATATYPE

# %%
# string is a sequence of characters used to represent text

# %%
"Orange"
# Out:
# 'Orange'

# %%
"Kenya"
# Out:
# 'Kenya'

# %%
#string concantenation is the joining of two or more strings

# %%
a = "Manu"
b = "Igathe"

# %%
a + b
# Out:
# 'ManuIgathe'

# %%
a+ " "+b
# Out:
# 'Manu Igathe'

# %%
print(a+" "+b)
# Out:
# Manu Igathe

# %%
#use the print() function to get rid of the string delimiter
